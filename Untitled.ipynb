# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
# %matplotlib inline
from models import VAE

# %%
X = np.load('./data/250k-T.npz')['arr'].astype(np.float32)
X = torch.from_numpy(X)

# %%
model = VAE()
model.eval()
Z = model.encode(X)[0].detach().numpy()
plt.scatter(Z[:, 0], Z[:, 1], s=1)

# %%
model.load_state_dict(torch.load('./models/vae-5.pth'))
model.eval()
Z = model.encode(X)[0].detach().numpy()
plt.scatter(Z[:, 0], Z[:, 1], s=1)

# %%
model.load_state_dict(torch.load('./models/vae-10.pth'))
model.eval()
Z = model.encode(X)[0].detach().numpy()
plt.scatter(Z[:, 0], Z[:, 1], s=1)

# %%
model.load_state_dict(torch.load('./models/vae-15.pth'))
model.eval()
Z = model.encode(X)[0].detach().numpy()
plt.scatter(Z[:, 0], Z[:, 1], s=1)

# %%
model.load_state_dict(torch.load('./models/vae-20.pth'))
model.eval()
Z = model.encode(X)[0].detach().numpy()
plt.scatter(Z[:, 0], Z[:, 1], s=1)

# %%
model.load_state_dict(torch.load('./models/vae-25.pth'))
model.eval()
Z = model.encode(X)[0].detach().numpy()
plt.scatter(Z[:, 0], Z[:, 1], s=1)

# %%
model.load_state_dict(torch.load('./models/vae-30.pth'))
model.eval()
Z = model.encode(X)[0].detach().numpy()
plt.scatter(Z[:, 0], Z[:, 1], s=1)

# %%
model.load_state_dict(torch.load('./models/vae-35.pth'))
model.eval()
Z = model.encode(X)[0].detach().numpy()
plt.scatter(Z[:, 0], Z[:, 1], s=1)

# %%
model.load_state_dict(torch.load('./models/vae-40.pth'))
model.eval()
Z = model.encode(X)[0].detach().numpy()
plt.scatter(Z[:, 0], Z[:, 1], s=1)

# %%
model.load_state_dict(torch.load('./models/vae-45.pth'))
model.eval()
Z = model.encode(X)[0].detach().numpy()
plt.scatter(Z[:, 0], Z[:, 1], s=1)
